# %% [markdown]
# <a href="https://colab.research.google.com/github/nikpaw/my_first_repo/blob/main/model_scheme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
final_data_cleaned = pd.DataFrame(
    {
     "Ab.-Score 61 (AUT) - Migrant Background share": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14   ],
     "Ab.-Score 61 (AUT) - Foreigner share": [176   ,  170   ,np.nan   ,  19   , 24   , 21   ,np.nan   ,np.nan   ,np.nan   ,  18   ,np.nan   ,  25   ,  42   , 7   ,np.nan   ,np.nan   ],
     "Ab.-Score 61 (AUT) - Distance": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14     ],
     "Ab.-Score 78 (BEL) - Migrant Background share": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14     ],
     "Ab.-Score 78 (BEL) - Foreigner share": [176   ,  170   ,np.nan   ,  19   , 24   , 21   ,np.nan   ,np.nan   ,np.nan   ,  18   ,np.nan   ,  25   ,  42   , 7   ,np.nan   ,np.nan      ],
     "Ab.-Score 78 (BEL) - Distance": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14     ],
     "Abortion Score 002 Countrycode () - Migrant Background share": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14     ],
     "Abortion Score 002 Countrycode () - Foreigner share": [176   ,  170   ,np.nan   ,  19   , 24   , 21   ,np.nan   ,np.nan   ,np.nan   ,  18   ,np.nan   ,  25   ,  42   , 7   ,np.nan   ,np.nan   ],
     "Abortion Score 002 Countrycode () - Distance": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14     ],
     "Abortion Score 003 Countrycode () - Migrant Background share": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14   ],
     "Abortion Score 003 Countrycode () - Foreigner share": [176   ,  170   ,np.nan   ,  19   , 24   , 21   ,np.nan   ,np.nan   ,np.nan   ,  18   ,np.nan   ,  25   ,  42   , 7   ,np.nan   ,np.nan   ],
     "Abortion Score 003 Countrycode () - Distance": [325   ,  286   ,  39   ,  46   ,  55   ,  32   ,np.nan   ,np.nan   ,np.nan   ,  27   ,np.nan   ,  28   ,  60   ,  18   ,np.nan   ,  14   ],
     "Abortions on Foreigners": [9, 19, 200, 267, 2, 2, 6, 4, 1,  9, np.nan,  13,  21,  15, 1,  1],
     "Abortions on Germans": [8965,  11325,  8570,  2824,  2218,  3952, 8144, 2042, 7189, 20216, 2635, 1961, 5187, 3007, 2946, 2845]
     }
     )



final_data_cleaned = final_data_cleaned.rename(
    index={
        0: "Baden-Württemberg",
        1: "Bavaria",
        2: "Berlin",
        3: "Brandenburg",
        4: "Bremen",
        5: "Hamburg",
        6: "Hesse",
        7: "Mecklenburg Western Pomerania",
        8: "Lower Saxony",
        9: "Northrhine-Westphalia",
        10: "Rhineland Palatinate",
        11: "Saarland",
        12: "Sachsen",
        13: "Sachsen-Anhalt",
        14: "Schleswig-Holstein",
        15: "Thuringia"
        }
        )

# %%
final_data_cleaned
# Out:
#                                Ab.-Score 61 (AUT) - Migrant Background share  \
# Baden-Württemberg                                                      325.0
# Bavaria                                                                286.0
# Berlin                                                                  39.0
# Brandenburg                                                             46.0
# Bremen                                                                  55.0
# Hamburg                                                                 32.0
# Hesse                                                                    NaN
# Mecklenburg Western Pomerania                                            NaN
# Lower Saxony                                                             NaN
# Northrhine-Westphalia                                                   27.0
# Rhineland Palatinate                                                     NaN
# ...
